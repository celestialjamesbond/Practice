# %%
pip install requests

# %%
pip install fake_useragent

# %%
pip install beautifulsoup
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
count=0
products=[]
prices=[]
ratings=[]

df=pd.DataFrame()

product_name='essential-oils'
url = 'https://www.vedaoils.com/collections/essential-oils'
print(url)
# Out:
# https://www.vedaoils.com/collections/essential-oils

# %%
  url='https://www.vedaoils.com/collections/essential-oils'

  print(url)
  page=requests.get(url)
  print(page)
  html=page.content

  page_soup=bs4.BeautifulSoup(html,'html.parser')
# Out:
# https://www.vedaoils.com/collections/essential-oils
# <Response [200]>

# %%
page=requests.get(url)
print(page)
html=page.content
rcount=0

page_soup=bs4.BeautifulSoup(html,'html.parser')
for containers in page_soup.findAll('div',attrs={'id':'AjaxinateContainer'}):
  name=containers.find('div',attrs={'class':'h4 grid-view-item-title'})
  price=containers.find('span',attrs={'class':'money'})
  rating=containers.find('div',attrs={'class':'loox-rating'})

  for i in range(1,6):
    if containers.find('i',attrs={'class':'loox-icon loox-star'}):
      rcount+=rcount
  #print('Specification:',specification.text)
  count+=count
  df=pd.DataFrame({'Product_name':products,'Price':prices,'Rating':rcount})
  print(df)
print('No of rows searched',count)
# Out:
# <Response [200]>
# Empty DataFrame
# Columns: [Product_name, Price, Rating]
# Index: []
# No of rows searched 0
