# %%
a = input('enter value for a:')
print('vlaue entered for a is :' + a)
b = input('enter value for b:')
print('vlaue entered for b is :' + b)
c = input('enter value for c:')
print('vlaue entered for c is :' + c)

if a>b>c :
  print('a is the biggest value')
elif a>b and a<=c :
  print('a is greater than b but not greater or equal to c')
elif a < b and a >= c :
  print('a is smaller than b and it is greater or equal to c')3
# Out:
# enter value for a:4
# vlaue entered for a is :4
# enter value for b:6
# vlaue entered for b is :6
# enter value for c:3
# vlaue entered for c is :3
# a is smaller than b and it is greater or equal to c
