# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

Charting_Link = 'https://chartink.com/screener'
Charting_Url = 'https://chartink.com/screener/process'

# %%
condition = '( {57960} ( [0] 15 minute close > [-1] 15 minute max ( 20 , [0] 15 minute close ) and [0] 15 minute volume > [0] 15 minute sma ( volume,20 ) ) ) '

# %%
def getDataFromChartink(payload):
  payload = {'scan_clue':payload}

  with requests.Session() as s:
      url = 'https://chartink.com/screener/15-minute-stock-breakouts'
      r = s.get(Charting_Link)
      soup = BeautifulSoup(r.text, 'html.parser')
      csrf = soup.select_one('[name="csrf-token"]')['content']
      s.headers['x-csrf-token'] = csrf
      r=s.post(Charting_Url, data=payload)

      df=pd.DataFrame()
      for item in r.json()['data']:
          df=df.append(item,ignore_index=True)
  return df

# %%
data=getDataFromChartink(condition)

# %%
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
indices=['NIFTY','BANKNIFTY']

# %%
def fetchOptionChainfromNSE(script):
    if script in indices:
        url = f"https://www.nseindia.com/option-chain?symbol={script}"
    else:
        symbol4NSE = script.replace('&','%26')  # NSE uses %26 for & in symbol
        url = f"https://www.nseindia.com/option-chain?custom_select={symbol4NSE}"
    print(url)
    a=requests.get(url)
    #print(a.json()['records'])
    return a.json()['records']

nsedata=fetchOptionChainfromNSE('INFY')
nsedata
# Out:
# https://www.nseindia.com/option-chain?custom_select=INFY
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-abc5c50216c3> in <module>
#      10     return a.json()['records']
#      11
# ---> 12 nsedata=fetchOptionChainfromNSE('INFY')
#      13 nsedata
#
# ...
