# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=e200da5119a4b9273f0e848a3c067e60601b4e0dc40d298a5bdb348c32e65eca
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
# IMPORT ALL THE REQUIRED LIBRARIES
from bs4 import BeautifulSoup as BS
import requests as req

url = "https://www.businesstoday.in/latest/economy"

webpage = req.get(url)
trav = BS(webpage.content, "html.parser")
M = 1
for link in trav.find_all('a'):

	# PASTE THE CLASS TYPE THAT WE GET
	# FROM THE ABOVE CODE IN THIS AND
	# SET THE LIMIT GREATER THAN 35
	if(str(type(link.string)) == "<class 'bs4.element.NavigableString'>"
	and len(link.string) > 35):

		print(str(M)+".", link.string)
		M += 1
# Out:
# 1. RBI not considering re-introduction of Rs 1,000 currency notes: Report
# 2. RBI’s tightrope walk: Supporting growth in the face of shrinking fiscal space and global turmoil
# 3. ‘We will always stand by China’: Pakistan PM says they trust China blindly, calls ties ‘sweeter than honey’
# 4. Uttarakhand govt inks MoUs worth Rs 54,550 cr with various industry groups
# 5. How banks can plug compliance loopholes amid RBI's penalty blitz
# 6. India Inc may get more GST notices in the coming weeks
# 7. Cartel curbs: CCI releases draft rules for leniency plus regime
# 8. Finance Ministry caps ad hoc bonus for central govt employees at Rs 7,000 ahead of festive season; here's how it's calculated
# 9. Govt cuts windfall tax on domestic crude, export of diesel, ATF
# 10. Chhattisgarh, Delhi record lowest retail inflation in all Indian states/UTs in September
# 11. Growing consensus on OECD global tax norms, but more work needed
# 12. 'Potential to compete with Singapore': How Adani Group's Vizhinjam Port is a maritime game changer for India
# 13. Delhi seeks 'sister city' agreement with Brisbane in Australia; here’s what it means
# 14. Wilful default cases on the rise: Banks filed suits against 36,150 NPA accounts to recover Rs 9.26 lakh cr in FY23
# 15. ‘Time to seek fair, accountable action from developed nations’: Gautam Adani on climate action
# 16. Food inflation worries persist in wholesale inflation data for September
# 17. WPI inflation falls 0.26% in September, in negative territory for sixth month in a row
# 18. Fuel price concerns are back due to Middle East crisis: FM Nirmala Sitharaman
# 19. India-UK FTA talks at an advanced stage, but difficult to set a timeline: Commerce Secretary
# 20. Israel-Palestine war likely to increase burden on Indian households
# 21. India’s exports decline 2.6% to $34.47 billion in September
