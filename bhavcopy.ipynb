# %%
pip install bhavcopy
# Out:
# Collecting bhavcopy
#   Downloading bhavcopy-3.0.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from bhavcopy) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bhavcopy) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bhavcopy) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bhavcopy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bhavcopy) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bhavcopy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bhavcopy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bhavcopy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bhavcopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->bhavcopy) (1.16.0)
# Building wheels for collected packages: bhavcopy
#   Building wheel for bhavcopy (setup.py) ... done
#   Created wheel for bhavcopy: filename=bhavcopy-3.0-py3-none-any.whl size=5314 sha256=5b211a072c4e729da66ddce2eb547b7d7c4bccaf0d93de8c71c12f03ff8c54a8
#   Stored in directory: /root/.cache/pip/wheels/98/6e/ec/d1ed7817d15c778faccd62848124dac5cb5d6acb28ef630f75
# Successfully built bhavcopy
# Installing collected packages: bhavcopy
# Successfully installed bhavcopy-3.0

# %%
import bhavcopy
import datetime as dt
# Place data need to be stored.

data_storage = "/content/drive/MyDrive/NSE"

# Define working directory, where files would be saved
#os.chdir(data_storage)
# Define start and end dates, and convert them into date format

start_date = dt.date(2023, 3, 1)
end_date = dt.date(2023, 3, 21)

# Define wait time in seconds to avoid getting blocked

wait_time = 1

# Instantiate bhavcopy class for equities, indices, and derivatives

nse = bhavcopy("equities", start_date, end_date, data_storage, wait_time)

nse.get_data()

nse = bhavcopy("derivatives", start_date, end_date, data_storage, wait_time)

nse.get_data()

nse = bhavcopy("indices", start_date, end_date, data_storage, wait_time)

nse.get_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-0e7658030e59> in <cell line: 20>()
#      18 # Instantiate bhavcopy class for equities, indices, and derivatives
#      19
# ---> 20 nse = bhavcopy("equities", start_date, end_date, data_storage, wait_time)
#      21
#      22 nse.get_data()
#
# TypeError: 'module' object is not callable
