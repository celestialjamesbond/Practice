# %%
sqares=[]
for i in range(11):
  sqares.append(i*i)
print(sqares)
def checkleapyear(x):
  if x % 4==0 :
    print('Entered year is a leap year: ' + x)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
